# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

p1 = Image.open("pritish.JPG")


p1_array = np.asarray(p1)

plt.imshow(p1_array
          )

p1_copy = p1_array.copy()
